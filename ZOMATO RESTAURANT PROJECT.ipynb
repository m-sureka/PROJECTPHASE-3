# %% [markdown]
# # PHASE 3- ZOMATO RESTAURANT PROJECT

# %% [markdown]
# Project Description
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget.
# This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its
# Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different
# currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
#
# 1) Average Cost for two
#
# 2) Price range

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('zomato.csv')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df2=pd.read_csv('Country-code.csv')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=pd.merge(df1,df2)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# Checking the datatypes of the columns-

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df.tail(10)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9541        5905215           Emirgan S�_ti��           208  ��stanbul
# 9542        5926979            Leman K�_lt�_r           208  ��stanbul
# 9543        5916085              Dem Karak�_y           208  ��stanbul
# 9544        5915547     Karak�_y G�_ll�_o��lu           208  ��stanbul
# 9545        5915054                  Baltazar           208  ��stanbul
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address         Locality  \
# 9541  Emirgan Mahallesi, Sak۱p Sabanc۱ Caddesi, No 4...         Emirg��n
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# Checking null values in the dataframe

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df=df.apply(lambda x: x.fillna(x.value_counts().index[0]))
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# We see there are no nan values in the dataset.

# %% [markdown]
# Dropping irrelevant columns which might cause errors and ambiguity-

# %%
df=df.drop(['Restaurant ID','Address','Locality','Longitude','Latitude'],axis=1)
df
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546               Naml۱ Gurme           208         ��stanbul
# 9547              Ceviz A��ac۱           208         ��stanbul
# 9548                     Huqqa           208         ��stanbul
# 9549               A���k Kahve           208         ��stanbul
# 9550  Walter's Coffee Roastery           208         ��stanbul
#
#                                        Locality Verbose  \
# 0     Century City Mall, Poblacion, Makati City, Mak...
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...
# ...

# %% [markdown]
# We can now move forward with the EDA and model building steps.
#
# Steps to be followed in projects-
#
# We need to apply feature engineering/ EDA on the dataset.
#
# After that we can split the dataset into train_model and test_model; use this train_model to train your model and test_model to validate your model.
#
# After splitting the dataset we need to train at least 4-5 models.
#
# Check performance of each model
#
# For regression problem- create regression model and check the r2 score and metrics of each model .
#
# Check the cross validation score for each model(for classification as well as for regression model).
#
# Choose the model as the best model.
#
# For regression problem- model with least difference between performance parameter and cross validation computed on same performance parameter is the best model. Example- Difference between r2 score and cross validation computed on r2
# scoring parameter.
#
# Perform hyper parameter tuning on the best model and check performance of the best model.
#
# Save the best model.
#
# Steps in EDA and Preprocessing:
#
# Identification of variables and data types
#
# Analyzing the basic metrics
#
# Non-Graphical Univariate Analysis
#
# Missing value treatment
#
# Graphical Univariate Analysis
#
# Bivariate Analysis
#
# Encoding the categorical Data
#
# Outlier treatment
#
# Variable transformations
#
# Correlation Analysis
#
# Dimensionality Reduction
#
# Scaling of Independent features

# %%
df['Average Cost for two'].unique()
# Out:
# array([  1100,   1200,   4000,   1500,   1000,   2000,   6000,    800,
#           900,    700,    850,    600,   3000,   1800,     55,     30,
#            45,     60,     50,     80,     90,    200,    150,    100,
#           230,    240,    350,    140,    170,    120,    250,     40,
#            70,    300,     85,     75,    400,     65,     25,     10,
#             0,     35,     20,      7,    270,    500,    430,    315,
#           220,     95,    190,    260,    180,    330,    280,    160,
#           285,    130,    110,   2500,   3600,    550,   1400,    450,
#           950,    650,   1300,   2400,   1600,   2200,    750,   1700,
#          1250,   1900,   2700,   3500,   5000,   2300,   1750,   3200,
#          2100,   1850,   4500,   3300,   1350,   1650,   1950,   1050,
#           290,   1450,   2800,   3650,   4800,   1550,    720,   6500,
#          7000,   1150,   2900,   2600,   4700,   3700,   3800,   4100,
# ...

# %%
df['Average Cost for two'].nunique()
# Out:
# 140

# %%
df.loc[df['Average Cost for two']==' ']
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality Verbose, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %% [markdown]
# We see there are no blank spaces are present in the dataframe.
#
# EDA-
#
# UNIVARIATE ANALYSIS-

# %%
import seaborn as sns
sns.countplot(x='City',data=df)
print(df['City'].value_counts())
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64

# %%
sns.countplot(x='Cuisines',data=df)
print(df['Cuisines'].value_counts())
# Out:
# North Indian                                             945
# North Indian, Chinese                                    511
# Fast Food                                                354
# Chinese                                                  354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
sns.displot(df['Average Cost for two'],kde=True)

# %%
sns.countplot(x='Currency',data=df)
print(df['Currency'].value_counts())
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
sns.countplot(x='Has Table booking',data=df)
print(df['Has Table booking'].value_counts())
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %%
sns.countplot(x='Has Online delivery',data=df)
print(df['Has Online delivery'].value_counts())
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
sns.countplot(x='Is delivering now',data=df)
print(df['Is delivering now'].value_counts())
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %%
sns.countplot(x='Switch to order menu',data=df)
print(df['Switch to order menu'].value_counts())
# Out:
# No    9551
# Name: Switch to order menu, dtype: int64

# %%
sns.countplot(x='Price range',data=df)
print(df['Price range'].value_counts())
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
sns.displot(df['Aggregate rating'],kde=True)

# %%
sns.countplot(x='Rating color',data=df)
print(df['Rating color'].value_counts())
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %%
sns.countplot(x='Rating text',data=df)
print(df['Rating text'].value_counts())
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
sns.displot(df['Votes'],kde=True)

# %%
sns.countplot(x='Country',data=df)
print(df['Country'].value_counts())
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# BIVARIATE ANALYSIS-

# %%
sns.scatterplot(x='Restaurant Name',y='Aggregate rating',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Aggregate rating'>

# %%
sns.scatterplot(x='Restaurant Name',y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x='Restaurant Name',y='Votes',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Votes'>

# %% [markdown]
# MULTIVARIATE ANALYSIS-

# %%
sns.pairplot(data=df)

# %% [markdown]
# After EDA we conclude that most of the restaurants average rating lies above 4.0 which a great sign for Zomato and its customers. The price range is divided into 4 parts and 1 has the highest number of restaurants falling into it. However, the rating colour is orange and text is average on most restaurants which needs to be looked upon and imporved.

# %% [markdown]
# Encoding the dataset-

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Restaurant Name  Country Code   City  Locality Verbose  Cuisines  \
# 0              3749.0           162   73.0             172.0     920.0
# 1              3173.0           162   73.0             601.0    1111.0
# 2              2897.0           162   75.0             314.0    1671.0
# 3              4707.0           162   75.0             875.0    1126.0
# 4              5523.0           162   75.0             875.0    1122.0
# ...               ...           ...    ...               ...       ...
# 9546           4443.0           208  140.0             523.0    1813.0
# 9547           1311.0           208  140.0             558.0    1824.0
# 9548           3069.0           208  140.0             561.0    1110.0
# 9549            513.0           208  140.0             561.0    1657.0
# 9550           7240.0           208  140.0             681.0     331.0
#
#       Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# ...

# %% [markdown]
# Describing the dataset-

# %%
df.describe()
# Out:
#        Restaurant Name  Country Code         City  Locality Verbose  \
# count      9551.000000   9551.000000  9551.000000       9551.000000
# mean       3653.204586     18.365616    78.301434        677.305204
# std        2142.917876     56.750546    23.198915        331.727817
# min           0.000000      1.000000     0.000000          0.000000
# 25%        1777.500000      1.000000    76.000000        387.000000
# 50%        3595.000000      1.000000    88.000000        707.000000
# 75%        5485.500000      1.000000    88.000000        953.000000
# max        7445.000000    216.000000   140.000000       1264.000000
#
#           Cuisines  Average Cost for two     Currency  Has Table booking  \
# count  9551.000000           9551.000000  9551.000000        9551.000000
# mean    989.461732           1199.210763     3.977699           0.121244
# std     514.176108          16121.183073     0.914242           0.326428
# ...

# %% [markdown]
# Describing the dataset gives us an understanding of various values like count of the attribute,mean of that attribute, standard deviation, minimum, 25th percentile, median/50th percentile, 75th percentile and the maximum value of that attribute.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation of the columns with the target column-

# %%
df.corr()['Average Cost for two'].sort_values()
# Out:
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality Verbose       -0.011852
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005831
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking whether the columns are positively or negatively correlated with the target column.

# %%
plt.figure(figsize=(22,7))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=14)
plt.show()

# %%
df.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Locality Verbose        -0.183059
# Cuisines                -0.307425
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# Keeping +/-5.0 as the range for skewness, here are the columns which do not lie within the range- Is delivering now
#
# Since no column has skewness, we will not treat them.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       9551 non-null   float64
#  1   Country Code          9551 non-null   int64
#  2   City                  9551 non-null   float64
#  3   Locality Verbose      9551 non-null   float64
#  4   Cuisines              9551 non-null   float64
#  5   Average Cost for two  9551 non-null   int64
#  6   Currency              9551 non-null   float64
#  7   Has Table booking     9551 non-null   float64
#  8   Has Online delivery   9551 non-null   float64
#  9   Is delivering now     9551 non-null   float64
#  10  Switch to order menu  9551 non-null   float64
#  11  Price range           9551 non-null   int64
#  12  Aggregate rating      9551 non-null   float64
#  13  Rating color          9551 non-null   float64
# ...

# %% [markdown]
# From the above code we can have the columns datatype and the memory used by the dataframe.

# %% [markdown]
# Checking for outliers on the int and float type of columns-

# %%
df['Cuisines'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Average Cost for two'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Has Online delivery'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Price range'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Aggregate rating'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Votes'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Considering the outlier removal-

# %%
df.shape
# Out:
# (9551, 17)

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550]),
#  array([6, 6, 6, ..., 6, 1, 6]))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
# Empty DataFrame
# Columns: [Restaurant Name, Country Code, City, Locality Verbose, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %% [markdown]
# Separating the columns into features and target-

# %%
features=df.drop('Average Cost for two',axis=1)
target=df['Average Cost for two']

# %% [markdown]
# 1) PREDICTING AVERAGE COST FOR TWO- LINEAR REGRESSION MODEL

# %% [markdown]
# Scaling the data using MinMax scaler-

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f'At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is:- {r2_score(target_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is:- 0.036469751906806125
# At random state 0,the testing accuracy is:- 0.04805857042966233
#
#
# At random state 1,the training accuracy is:- 0.047266336008908616
# At random state 1,the testing accuracy is:- 0.028192771761174407
#
#
# At random state 2,the training accuracy is:- 0.04300070493717112
# At random state 2,the testing accuracy is:- 0.006208701815273776
#
#
# At random state 3,the training accuracy is:- 0.04342663745316244
# At random state 3,the testing accuracy is:- 0.0038401668780827514
#
#
# At random state 4,the training accuracy is:- 0.048854371750508996
# At random state 4,the testing accuracy is:- -0.2514845735891318
#
#
# At random state 5,the training accuracy is:- 0.047022418704713465
# At random state 5,the testing accuracy is:- 0.028163215129255348
#
#
# At random state 6,the training accuracy is:- 0.04553561961199448
# At random state 6,the testing accuracy is:- 0.0005842635462842694
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=99)

# %% [markdown]
# We choose random state as 99 because the difference between training and testing accuracy is the least there

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.03983862457310172

# %% [markdown]
# Cross validation of the model-

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is -861.1557851084592 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# At cross fold 3 the cv score is -744.3914628594874 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# At cross fold 4 the cv score is -689.9054692827942 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# At cross fold 5 the cv score is -712.173661793177 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# At cross fold 6 the cv score is -684.4932218074631 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# At cross fold 7 the cv score is -779.6402424733402 and accuracy score for training is 0.0411624059066934 and accuracy for the testing is 0.03983862457310172
#
#
# ...

# %% [markdown]
# Here, we have handled the problem of the overfitting and the underfitting by checking the training and testing score.

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test,color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Cost for 2',fontsize=14)
plt.ylabel('Predicted Cost for 2',fontsize=14)
plt.title('Linear Regression',fontsize=14)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# Best fit line is covering most of the datapoints which shows good fit of our model. Equation of the line is: y=mx+c
#
# Regularization-

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters={'alpha': [.0001, .001, .01, .1, 1, 10],
           'random_state':list(range(0,10))}
ls=Lasso()
clf= GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %% [markdown]
# Final model training-

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(features_test,target_test)
ls_score_testing=ls.score(features_test,target_test)
pred_ls=ls.predict(features_test)
ls_score_testing*100
# Out:
# 5.278272395383555

# %% [markdown]
# Here, we predict the score on our test data to check the model accuracy.
#
# Ensemble technique-

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion': ['mse','mae'],
           'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf= GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
from sklearn.model_selection import cross_val_score

# %%
rf=RandomForestRegressor(criterion='mae',max_features='log2')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision= rf.predict(features_test)
rfs=r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,features,target,cv=7)
rfc= rfscore.mean()
print('Cross val score:',rfc*100)
# Out:
# R2 Score: 57.29957633952534
# Cross val score: -33722.71541647653

# %% [markdown]
# We are getting model accuracy above 57% which shows our model is performing good. We choose cv=7 here because, the accuracy score there is the highest.
#
# Saving the file-

# %%
import pickle
filename='zomato.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# Conclusion-

# %%
loaded_model=pickle.load(open('zomato.pkl','rb'))
result=loaded_model.score(features_test,target_test)
print(result*100)
# Out:
# 57.29957633952534

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['Predicted','Original'])
conclusion
# Out:
#             0      1      2      3      4       5      6        7      8     \
# Predicted  278.5  636.5  265.5  599.5  291.0  329.75  581.5  23336.0  258.5
# Original   278.5  636.5  265.5  599.5  291.0  329.75  581.5  23336.0  258.5
#
#             9     ...   1901   1902   1903    1904   1905   1906   1907  \
# Predicted  347.5  ...  269.0  29.95  310.5  604.25  285.5  659.0  649.5
# Original   347.5  ...  269.0  29.95  310.5  604.25  285.5  659.0  649.5
#
#             1908   1909   1910
# Predicted  32.55  165.0  509.5
# Original   32.55  165.0  509.5
#
# [2 rows x 1911 columns]

# %% [markdown]
# 2) PREDICTING PRICE RANGE- MULTI CLASS CLASSIFICATION MODEL

# %%
x=df.drop('Price range',axis=1)
y=df['Price range']

# %% [markdown]
# x is independent variable and y is target variable.

# %% [markdown]
# Oversampling the data-

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 3    4444
# 4    4444
# 2    4444
# 1    4444
# Name: Price range, dtype: int64

# %% [markdown]
# CLASSIFICATION MODEL-

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score

# %% [markdown]
# Splitting the dataframe-

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,i)==round(accuracy_score(y_test,pred_test)*100,i):
        print('At random state',i,'The model performs very well')
        print('At random state: ',i)
        print('Training accuracy is:',accuracy_score(y_train,pred_train)*100)
        print('Testing accuracy is:',accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 1 The model performs very well
# At random state:  1
# Training accuracy is: 60.35864978902954
# Testing accuracy is: 60.404949381327334
# At random state 307 The model performs very well
# At random state:  307
# Training accuracy is: 60.74542897327707
# Testing accuracy is: 60.17997750281214
# At random state 308 The model performs very well
# At random state:  308
# Training accuracy is: 60.661040787623065
# Testing accuracy is: 61.33295838020247

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=1)

# %% [markdown]
# We take random state as 1 because the difference between training and testing accuracy is the least there.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.26      0.27      0.27       888
#            2       0.25      0.25      0.25       879
#            3       0.24      0.23      0.24       871
#            4       0.26      0.24      0.25       918
#
#     accuracy                           0.25      3556
#    macro avg       0.25      0.25      0.25      3556
# weighted avg       0.25      0.25      0.25      3556

# %% [markdown]
# Cross validation score-

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print('At cv:',j)
    print('Cross validation score is',lsc*100)
    print('Accuracy score is',lss*100)
    print('\n')
# Out:
# At cv: 2
# Cross validation score is 56.01935193519352
# Accuracy score is 60.26434195725534
#
#
# At cv: 3
# Cross validation score is 58.444383685710264
# Accuracy score is 60.26434195725534
#
#
# At cv: 4
# Cross validation score is 58.93901890189019
# Accuracy score is 60.26434195725534
#
#
# At cv: 5
# Cross validation score is 59.18680101696149
# Accuracy score is 60.26434195725534
#
#
# At cv: 6
# Cross validation score is 59.55836781783644
# Accuracy score is 60.26434195725534
#
#
# At cv: 7
# Cross validation score is 59.64859773583836
# Accuracy score is 60.26434195725534
#
#
# At cv: 8
# Cross validation score is 60.210396039603964
# Accuracy score is 60.26434195725534
#
#
# At cv: 9
# Cross validation score is 59.339457455713294
# Accuracy score is 60.26434195725534

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=8).mean()
print('The cv score is',lsscore_selected,'\n The accuracy score is',lss)
# Out:
# The cv score is 0.6021039603960396
#  The accuracy score is 0.6026434195725534

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9780652418447694
# [[887   1   0   0]
#  [ 11 855  10   3]
#  [  0  17 832  22]
#  [  0   0  14 904]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       888
#            2       0.98      0.97      0.98       879
#            3       0.97      0.96      0.96       871
#            4       0.97      0.98      0.98       918
#
#     accuracy                           0.98      3556
#    macro avg       0.98      0.98      0.98      3556
# weighted avg       0.98      0.98      0.98      3556

# %%
score=cross_val_score(RFC,x,y,cv=8)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross validation score is: ',accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.88568857 0.9729973  0.96984698 0.99054905 0.98739874 0.95139514
#  0.97524752 0.96489649]
# 0.9622524752475248
# Difference between Accuracy score and cross validation score is:  0.01581276659724462

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7485939257592801
# [[860  27   1   0]
#  [116 739  24   0]
#  [134 118 561  58]
#  [232  56 128 502]]
#               precision    recall  f1-score   support
#
#            1       0.64      0.97      0.77       888
#            2       0.79      0.84      0.81       879
#            3       0.79      0.64      0.71       871
#            4       0.90      0.55      0.68       918
#
#     accuracy                           0.75      3556
#    macro avg       0.78      0.75      0.74      3556
# weighted avg       0.78      0.75      0.74      3556

# %% [markdown]
# Checking cv score for Support vector machine classifier-

# %%
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross validation score is: ',accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.70191226 0.71476793 0.75752461 0.75049226 0.74345992]
# 0.7336313973411551
# Difference between Accuracy score and cross validation score is:  0.014962528418124954

# %% [markdown]
# Checking accuracy score for Gradient Boosting Classifier-

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.9603487064116986
# [[888   0   0   0]
#  [ 11 849  16   3]
#  [  0  20 807  44]
#  [  0   0  47 871]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       888
#            2       0.98      0.97      0.97       879
#            3       0.93      0.93      0.93       871
#            4       0.95      0.95      0.95       918
#
#     accuracy                           0.96      3556
#    macro avg       0.96      0.96      0.96      3556
# weighted avg       0.96      0.96      0.96      3556

# %% [markdown]
# Checking cv score for Gradient Boosting Classifier-

# %%
score=cross_val_score(GB,x,y)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross validation score is: ',accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.74775028 0.95668073 0.96652602 0.93783404 0.94964838]
# 0.9116878902795378
# Difference between Accuracy score and cross validation score is:  0.04866081613216078

# %% [markdown]
# Checking accuracy score using KNN-

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=11)
knn.fit(x_train,y_train)
pr=knn.predict(x_test)
print(pr)
print('Accuracy score is:', accuracy_score(y_test,pr))
print(confusion_matrix(y_test,pr))
print(classification_report(y_test,pr))
# Out:
# [3 2 4 ... 2 3 3]
# Accuracy score is: 0.8655793025871766
# [[786  54   9  39]
#  [ 82 723  50  24]
#  [ 25  38 750  58]
#  [ 40  14  45 819]]
#               precision    recall  f1-score   support
#
#            1       0.84      0.89      0.86       888
#            2       0.87      0.82      0.85       879
#            3       0.88      0.86      0.87       871
#            4       0.87      0.89      0.88       918
#
#     accuracy                           0.87      3556
#    macro avg       0.87      0.87      0.87      3556
# weighted avg       0.87      0.87      0.87      3556

# %% [markdown]
# Checking cv score for KNN-

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print('Difference between Accuracy score and cross validation score is: ',accuracy_score(y_test,pr)-score.mean())
# Out:
# [0.78093363 0.82672293 0.8745429  0.89057665 0.88495077]
# 0.8515453764481972
# Difference between Accuracy score and cross validation score is:  0.014033926138979469

# %% [markdown]
# We see that RFC is the best model here because it has the least difference between Accuracy score and Cross Validation Score.
#
# Hyper parameter tuning-

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'n_estimators': [200,500],
           'max_features': ['auto','sqrt','log2'],
           'max_depth': [4,5,6,7,8],
           'criterion': ['gini','entropy']}

# %%
grid=GridSearchCV(RFC,param_grid,cv=8)

# %%
grid.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 grid.fit(x_train,y_train)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
# ...

# %%
print(grid.best_params_)

# %%
print(grid.best_estimator_)

# %%
grid_predictions=grid.predict(x_test)
grid_predictions

# %%
print(classification_report(y_test,grid_predictions))

# %% [markdown]
# Accuracy score is 89% which means our model is performing very good.
#
# AUC ROC CURVE-

# %% [markdown]
# It is used on Binary classification models. Since our model is a multiclass classification model, we will not plot it.
#
# Model Saving-

# %%
import pickle
filename='inhouse_zomato.pk1'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# Conclusion-

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_com

# %% [markdown]
# We can visualize that there is very minimal error in the outcome using the above model.

# %% [markdown]
# THE END

# %% [markdown]
# WHEN I RAN THE NOTEBOOK SECOND TIME, KERNEL IS HANGING AGAIN AND AGAIN, I HAVE WRITTEN THE CODES AND FINDINGS THOUGH.
